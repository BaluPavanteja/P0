# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# imported pandas library for data manupulation

# %%
customer_data=pd.read_json('C:/Users/Home/Revature/DataSets/customers.json')

# %%
# read customer_data which is in json format

# %%
customer_data
# Out:
#      customer_id     customer_name      country           city
# 0           9780      Jessica Hart   Martinique  South William
# 1           9169         Amy Clark   Kazakhstan     Davisville
# 2           6631  Danielle Elliott      Armenia     East Danny
# 3           8772     Robin Mendoza       Uganda    Johnsonbury
# 4           8913    Abigail Miller      Namibia  Wrightchester
# ..           ...               ...          ...            ...
# 995         6357    Jessica Castro     Dominica     Deannastad
# 996          244    Cheryl Ramirez       Malawi  Martinezmouth
# 997         4490   Luis Strickland        Italy     Oneilltown
# 998         2984    Jennifer Kelly      Bahamas    Xavierville
# 999         8760    Anthony Wilson  Switzerland      Torreston
#
# [1000 rows x 4 columns]

# %%
customer_data=pd.DataFrame(customer_data)
customer_data
# Out:
#      customer_id     customer_name      country           city
# 0           9780      Jessica Hart   Martinique  South William
# 1           9169         Amy Clark   Kazakhstan     Davisville
# 2           6631  Danielle Elliott      Armenia     East Danny
# 3           8772     Robin Mendoza       Uganda    Johnsonbury
# 4           8913    Abigail Miller      Namibia  Wrightchester
# ..           ...               ...          ...            ...
# 995         6357    Jessica Castro     Dominica     Deannastad
# 996          244    Cheryl Ramirez       Malawi  Martinezmouth
# 997         4490   Luis Strickland        Italy     Oneilltown
# 998         2984    Jennifer Kelly      Bahamas    Xavierville
# 999         8760    Anthony Wilson  Switzerland      Torreston
#
# [1000 rows x 4 columns]

# %%
customer_data.tail()
# Out:
#      customer_id    customer_name      country           city
# 995         6357   Jessica Castro     Dominica     Deannastad
# 996          244   Cheryl Ramirez       Malawi  Martinezmouth
# 997         4490  Luis Strickland        Italy     Oneilltown
# 998         2984   Jennifer Kelly      Bahamas    Xavierville
# 999         8760   Anthony Wilson  Switzerland      Torreston

# %%
customer_data.isnull()
# Out:
#      customer_id  customer_name  country   city
# 0          False          False    False  False
# 1          False          False    False  False
# 2          False          False    False  False
# 3          False          False    False  False
# 4          False          False    False  False
# ..           ...            ...      ...    ...
# 995        False          False    False  False
# 996        False          False    False  False
# 997        False          False    False  False
# 998        False          False    False  False
# 999        False          False    False  False
#
# [1000 rows x 4 columns]

# %%
customer_data.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# country          0
# city             0
# dtype: int64

# %%
transaction_data=pd.read_json('C:/Users/Home/Revature/DataSets/transaction_logs.json')

# %%
transaction_data
# Out:
#       order_id  customer_id  product_id           product_name  \
# 0            1         1731        8609  Central home & kitche
# 1            2         5539        2409             Upon sport
# 2            3         3507        1145       Across stationer
# 3            4         4826        8375    Start home & kitche
# 4            5         6538        2149             Draw beaut
# ...        ...          ...         ...                    ...
# 9995      9996         1496        9676    Range home & kitche
# 9996      9997         7288        9927               Once toy
# 9997      9998         8381        3852            Human beaut
# 9998      9999         5494        7324            Light beaut
# 9999     10000         1490        6547        Source furnitur
#
#      product_category      payment_type  qty  price            datetime  \
# 0      Home & Kitchen            Wallet   25  64216 2021-07-26 20:16:14
# ...

# %%
transaction_data.tail()
# Out:
#       order_id  customer_id  product_id         product_name product_category  \
# 9995      9996         1496        9676  Range home & kitche   Home & Kitchen
# 9996      9997         7288        9927             Once toy             Toys
# 9997      9998         8381        3852          Human beaut           Beauty
# 9998      9999         5494        7324          Light beaut           Beauty
# 9999     10000         1490        6547      Source furnitur        Furniture
#
#           payment_type  qty  price            datetime ecommerce_website_name  \
# 9995            Wallet   39  61151 2024-03-17 09:06:05            www.ebay.in
# 9996  Internet Banking   44  53963 2024-06-17 08:04:22          www.amazon.in
# 9997               UPI   48  26032 2023-02-05 04:20:30       www.tatacliq.com
# 9998               UPI   17  28277 2024-02-17 03:05:57           www.etsy.com
# 9999               UPI   34  91020 2023-01-11 03:02:53       www.flipkart.com
#
# ...

# %%
transaction_data.head()
# Out:
#    order_id  customer_id  product_id           product_name product_category  \
# 0         1         1731        8609  Central home & kitche   Home & Kitchen
# 1         2         5539        2409             Upon sport           Sports
# 2         3         3507        1145       Across stationer       Stationery
# 3         4         4826        8375    Start home & kitche   Home & Kitchen
# 4         5         6538        2149             Draw beaut           Beauty
#
#   payment_type  qty  price            datetime ecommerce_website_name  \
# 0       Wallet   25  64216 2021-07-26 20:16:14        www.bestbuy.com
# 1         Card   34  69877 2021-08-25 03:41:32       www.flipkart.com
# 2         Card   28  35491 2024-06-21 21:39:21         www.target.com
# 3         Card   33  39540 2022-09-17 13:52:11          www.amazon.in
# 4         Card   27  80635 2022-03-09 07:58:08           www.etsy.com
#
#   payment_txn_id payment_txn_success       failure_reason
# ...

# %%
transaction_data.isna().sum()
# Out:
# order_id                  0
# customer_id               0
# product_id                0
# product_name              0
# product_category          0
# payment_type              0
# qty                       0
# price                     0
# datetime                  0
# ecommerce_website_name    0
# payment_txn_id            0
# payment_txn_success       0
# failure_reason            0
# dtype: int64

# %%
import mysql.connector

# %%
db=mysql.connector.connect(
    host="localhost",
    user="root",
    password="Pavan@mysql29",
    database="demo"
)

# %%
cursor=db.cursor()

# %%
cursor.execute("select * from customers")
result=cursor.fetchall()
for i in result:
    print(i)
# Out:
# (102, 'Kenneth Singh', 'Sweden', 'Davidhaven')
# (106, 'Mr. James Mendez', 'British Indian Ocean Territory (Chagos Archipelago)', 'Paulmouth')
# (109, 'Joseph Martin', 'Somalia', 'Port Vickiemouth')
# (135, 'Joann Romero', 'Timor-Leste', 'Port Raymondmouth')
# (144, 'Robert Reeves', 'Wallis and Futuna', 'Lake Jason')
# (145, 'Jasmine Dean', 'Tuvalu', 'Scotthaven')
# (147, 'Charles Becker', 'Isle of Man', 'East Cindyfurt')
# (158, 'Anthony Bowman', 'Latvia', 'Carriebury')
# (159, 'Desiree Edwards', 'Central African Republic', 'North Williammouth')
# (161, 'Kyle Lee', 'Greece', 'Jamesberg')
# (207, 'Dr. Michael Anderson Jr.', 'Guinea', 'Lake Amytown')
# (216, 'Pamela Conley', 'United Arab Emirates', 'Danamouth')
# (229, 'Amanda Castillo', 'Ghana', 'New Lorichester')
# (230, 'Amanda Dyer', 'Saint Vincent and the Grenadines', 'Johnsontown')
# (231, 'Crystal Stewart', 'Cook Islands', 'Greggville')
# (232, 'Emily Sanchez', 'United States Minor Outlying Islands', 'Vickiechester')
# ...

# %%
cursor.execute("select * from customers")
result=cursor.fetchall()
for i in result:
    print(i)
# Out:
# (102, 'Kenneth Singh', 'Sweden', 'Davidhaven')
# (106, 'Mr. James Mendez', 'British Indian Ocean Territory (Chagos Archipelago)', 'Paulmouth')
# (109, 'Joseph Martin', 'Somalia', 'Port Vickiemouth')
# (135, 'Joann Romero', 'Timor-Leste', 'Port Raymondmouth')
# (144, 'Robert Reeves', 'Wallis and Futuna', 'Lake Jason')
# (145, 'Jasmine Dean', 'Tuvalu', 'Scotthaven')
# (147, 'Charles Becker', 'Isle of Man', 'East Cindyfurt')
# (158, 'Anthony Bowman', 'Latvia', 'Carriebury')
# (159, 'Desiree Edwards', 'Central African Republic', 'North Williammouth')
# (161, 'Kyle Lee', 'Greece', 'Jamesberg')
# (207, 'Dr. Michael Anderson Jr.', 'Guinea', 'Lake Amytown')
# (216, 'Pamela Conley', 'United Arab Emirates', 'Danamouth')
# (229, 'Amanda Castillo', 'Ghana', 'New Lorichester')
# (230, 'Amanda Dyer', 'Saint Vincent and the Grenadines', 'Johnsontown')
# (231, 'Crystal Stewart', 'Cook Islands', 'Greggville')
# (232, 'Emily Sanchez', 'United States Minor Outlying Islands', 'Vickiechester')
# ...

# %%
cursor.execute("select * from transaction_logs limit 10")
result=cursor.fetchall()
for i in result:
    print(i)
# Out:
# (1, 1731, 8609, 'Central home & kitche', 'Home & Kitchen', 'Wallet', 25, 64216, '2021-07-26T20:16:14', 'www.bestbuy.com', 'a395e8c7', 'N', 'Card Expired')
# (2, 5539, 2409, 'Upon sport', 'Sports', 'Card', 34, 69877, '2021-08-25T03:41:32', 'www.flipkart.com', 'b40791f8', 'N', 'Invalid CVV')
# (3, 3507, 1145, 'Across stationer', 'Stationery', 'Card', 28, 35491, '2024-06-21T21:39:21', 'www.target.com', '7fb6cca9', 'N', 'Blocked Card')
# (4, 4826, 8375, 'Start home & kitche', 'Home & Kitchen', 'Card', 33, 39540, '2022-09-17T13:52:11', 'www.amazon.in', 'cae677f3', 'N', 'Transaction Timeout')
# (5, 6538, 2149, 'Draw beaut', 'Beauty', 'Card', 27, 80635, '2022-03-09T07:58:08', 'www.etsy.com', 'fbce1649', 'N', 'Invalid CVV')
# (6, 9648, 9729, 'Growth beaut', 'Beauty', 'UPI', 44, 62844, '2024-05-29T15:37:37', 'www.amazon.in', 'ebc84512', 'Y', '')
# (7, 7940, 453, 'Lose furnitur', 'Furniture', 'Wallet', 28, 21742, '2024-02-11T15:12:49', 'www.amazon.com', 'e407cea7', 'N', 'Invalid CVV')
# ...

# %%
customer_data.describe()
# Out:
#        customer_id
# count  1000.000000
# mean   5053.297000
# std    2792.627256
# min     102.000000
# 25%    2662.000000
# 50%    5156.000000
# 75%    7395.000000
# max    9991.000000

# %%
transaction_data.describe()
# Out:
#           order_id   customer_id   product_id           qty         price  \
# count  10000.00000  10000.000000  10000.00000  10000.000000  10000.000000
# mean    5000.50000   5540.854400   5153.96520     25.524800  49682.003700
# min        1.00000    109.000000    201.00000      1.000000     10.000000
# 25%     2500.75000   3141.500000   2709.75000     13.000000  24704.750000
# 50%     5000.50000   5989.000000   5195.00000     26.000000  49245.500000
# 75%     7500.25000   8341.500000   7599.00000     38.000000  74755.000000
# max    10000.00000   9991.000000   9996.00000     50.000000  99989.000000
# std     2886.89568   2776.686488   2828.45628     14.456946  28860.567215
#
#                             datetime
# count                          10000
# mean   2023-01-25 09:32:06.897900288
# min              2021-07-24 00:13:42
# 25%       2022-04-29 00:09:34.500000
# 50%              2023-01-22 13:19:27
# 75%              2023-10-28 13:48:13
# ...

# %%
transaction_data
# Out:
#       order_id  customer_id  product_id           product_name  \
# 0            1         1731        8609  Central home & kitche
# 1            2         5539        2409             Upon sport
# 2            3         3507        1145       Across stationer
# 3            4         4826        8375    Start home & kitche
# 4            5         6538        2149             Draw beaut
# ...        ...          ...         ...                    ...
# 9995      9996         1496        9676    Range home & kitche
# 9996      9997         7288        9927               Once toy
# 9997      9998         8381        3852            Human beaut
# 9998      9999         5494        7324            Light beaut
# 9999     10000         1490        6547        Source furnitur
#
#      product_category      payment_type  qty  price            datetime  \
# 0      Home & Kitchen            Wallet   25  64216 2021-07-26 20:16:14
# ...

# %%
transaction_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
customer_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
customer_data.dtypes
# Out:
# customer_id       int64
# customer_name    object
# country          object
# city             object
# dtype: object

# %%
transaction_data.dtypes
# Out:
# order_id                           int64
# customer_id                        int64
# product_id                         int64
# product_name                      object
# product_category                  object
# payment_type                      object
# qty                                int64
# price                              int64
# datetime                  datetime64[ns]
# ecommerce_website_name            object
# payment_txn_id                    object
# payment_txn_success               object
# failure_reason                    object
# dtype: object

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Users\Home\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# plt.figure(figsize=(10, 7))
# sns.heatmap(customer_data.isnull(), cbar=False, cmap='viridis')
# plt.show()

# %%
# Set up the matplotlib figure
plt.figure(figsize=(12, 6))

# Box plot for 'qty'
plt.subplot(1, 2, 1)
sns.boxplot(x=transaction_data['qty'])
plt.title('Box Plot of Quantity')

# Box plot for 'price'
plt.subplot(1, 2, 2)
sns.boxplot(x=transaction_data['price'])
plt.title('Box Plot of Price')

# Show the plot
plt.tight_layout()
plt.show()

# %%
numerical_columns = ['qty', 'price']

# Select only the numerical columns from the DataFrame
transaction_data = transaction_data[numerical_columns]

# Plot histograms for each numerical column
transaction_data.hist(figsize=(12, 10), bins=30, edgecolor='black')

# Show the plot
plt.suptitle('Histograms of Numerical Columns')
plt.show()

# %%
# Histogram for each numerical column
customer_data.hist(figsize=(12, 10), bins=30)
plt.show()

# %% [markdown]
# Normalization of the tables:

# %% [markdown]
# CREATION OF NORMALIZED TABLES (SUB TABLES)

# %%
db=mysql.connector.connect(
    host="localhost",
    user="root",
    password="Pavan@mysql29",
    database="revstore"
)
cursor=db.cursor()

# Create Customers Table

# cursor.execute("""CREATE TABLE customers (
#     customer_id INT PRIMARY KEY,
#     customer_name VARCHAR(255),
#     country VARCHAR(255),
#     city VARCHAR(255)
# );""")

# Create Products Table

# cursor.execute("""CREATE TABLE products (
#     product_id INT PRIMARY KEY,
#     product_name VARCHAR(255),
#     product_category VARCHAR(255)
# );""")

# -- Create Orders Table
# cursor.execute("""CREATE TABLE orders (
#     order_id INT PRIMARY KEY,
#     customer_id INT,
#     datetime DATETIME,
#     payment_type VARCHAR(255),
#     ecommerce_website_name VARCHAR(255),
#     payment_txn_id VARCHAR(255),
#     payment_txn_success VARCHAR(255),
#     failure_reason TEXT,
#     FOREIGN KEY (customer_id) REFERENCES customers(customer_id)
# );""")

#  Create Order Items Table

# cursor.execute("""CREATE TABLE order_items (
#     order_id INT,
#     product_id INT,
#     qty INT,
#     price INT,
#     PRIMARY KEY (order_id, product_id),
#     FOREIGN KEY (order_id) REFERENCES orders(order_id),
#     FOREIGN KEY (product_id) REFERENCES products(product_id)
# );""")

# %%
# Create a cursor object
db=mysql.connector.connect(
    host="localhost",
    user="root",
    password="Pavan@mysql29",
    database="revstore"
)
cursor=db.cursor()

# -------------------------------------------------------------------------------------

# Inserted data from customers_table into customers table


# insert_query = """
# INSERT INTO customers (customer_id, customer_name, country, city)
# SELECT customer_id, customer_name, country, city
# FROM customers_table
# """
# try:
#     cursor.execute(insert_query)
#     db.commit()  # Commit the transaction
#     print("Data has been successfully inserted.")
# except mysql.connector.Error as err:
#     print(f"Error: {err}")
# finally:
#     cursor.close()
#     db.close()

# --------------------------------------------------------------------------------

# INSERTED DATA INTO PRODUCTS TABLE FROM TRANSACTION_LOGS TABLE

# insert_query = """
# INSERT INTO products (product_id, product_name, product_category)
# SELECT product_id, product_name, product_category
# FROM transaction_logs
# ON DUPLICATE KEY UPDATE
#     product_name = VALUES(product_name),
#     product_category = VALUES(product_category);

# """
# try:
#     cursor.execute(insert_query)
#     db.commit()  # Commit the transaction
#     print("Data has been successfully inserted.")
# except mysql.connector.Error as err:
#     print(f"Error: {err}")
# finally:
#     cursor.close()
#     db.close()

# -----------------------------------------------------------------------------

# INSERTING DATA INTO ORDERS TABLE

# insert_query = """
# INSERT INTO orders (order_id, customer_id, datetime, payment_type, ecommerce_website_name, payment_txn_id, payment_txn_success, failure_reason)
# select order_id, customer_id, datetime, payment_type, ecommerce_website_name, payment_txn_id, payment_txn_success, failure_reason
# FROM transaction_logs;

# """
# try:
#     cursor.execute(insert_query)
#     db.commit()  # Commit the transaction
#     print("Data has been successfully inserted.")
# except mysql.connector.Error as err:
#     print(f"Error: {err}")
# finally:
#     cursor.close()
#     db.close()

# ----------------------------------------------------------------------------------

# INSERTED DATA INTO ORDER_ITEMS FROM TRANSACTION_LOGS

# insert_query = """
# INSERT INTO order_items (order_id, product_id, qty, price)
# select order_id, product_id, qty, price
# FROM transaction_logs;

# """
# try:
#     cursor.execute(insert_query)
#     db.commit()  # Commit the transaction
#     print("Data has been successfully inserted.")
# except mysql.connector.Error as err:
#     print(f"Error: {err}")
# finally:
#     cursor.close()
#     db.close()

# %% [markdown]
# Data is inserted into individual tables based on normalization rules.

# %%
cursor.execute("select * from products limit 5")
result=cursor.fetchall()
pd.DataFrame(result)
# for i in result:
#     print(i)

# t="select * from products limit 15"
# dff=pd.read_sql(t,con=db)
# dff
# Out:
#      0                 1            2
# 0  201          Song toy         Toys
# 1  202   Enjoy stationer   Stationery
# 2  203     Represent toy         Toys
# 3  206    Law electronic  Electronics
# 4  208  Issue electronic  Electronics
